# %% [markdown]
# # Part 1: Baseball Stats Explorations
# __This primer illustrates the basics of SQLite usage in Jupyter__

# %% [markdown]
# ## Boilerplate Setup Code
# Run this to set up %sql and %%sql magics

# %%
# %load_ext sql

# %% [markdown]
# ## First, a note about Jupyter Magics
# Jupyter supports lots of languages, with Python and Markdown being the defaults. However, we can easily mix in code other languages using so-called *magic* extensions. By prepending foreign code with a few *magic* characters (sort of like an incantation) the code that follows is then run, with any outputs translated into Jupyter's native namespace (data structures). So, we can have Python code call R code which calls Bash code ..., all with just a little magic.
#
# Jupyter magics generally start with the `%` character. A bunch of them are [built into Jupyter](https://ipython.readthedocs.io/en/stable/interactive/magics.html) without any installation required. A few useful ones:
# - `%cd`, which changes the directory in which the code that follows is run
# - `%load_ext`, which we saw used above to load the %sql and %%sql magics
# - `%matplotlb`, which sets up the matplotlib library for interactive use
# - `%%bash`, which executes Bash commands just like in a Terminal tab
# - `%%html`, which renders HTML code for direct display in the notebook
# - `%%js`, which executes Javascript code
#
# You may have noticed that some magics start with `%` while others start with `%%`.
# - The ones with `%` are run "inline" so they can be mixed directly into other code. This way one could for example, have Python code that directly calls SQL code to pull data from a database (without having to set up SqlAlchemy). If the magic code returns an output value, then that value can be captured with a variable. The ony real draw-back is that inline magics have to be on a single line and can's have any line breaks.
# - The ones with `%%` are _cell magics_ that apply to a whole cell. Cell magics are always by themselves on the first line of a cell. The code on the lines below are then processed via the magic. If the cell returns a value then it is displayed immediately by Jupyter. However, if we want to capture that value in a variable then we have to use a special [kludge](https://en.wikipedia.org/wiki/Kludge) included in Jupyter for just this purpose. In Jupyter, the special variable `_` (yes, that's an underscore) always contains the output value of the most recently run cell.
#
# __Here we will be using `%sql` and `%%sql` magics to pull data from a SQLite database.__

# %% [markdown]
# ## Connecting to the Database
# The database we will be using is the `Lahman 2016` data repository that you may have already seen in other classes. We are using it as a sort of common data set that conencts the courses. The database includes [historical baseball data from 1871-2016](https://github.com/jknecht/baseball-archive-sqlite).
#
# The database tech used is SQLite, a very lightweight package that keeps all data in a single file (sort of like a document) that can be copied and even versioned in GitHub. This has lots of advantages for business analysts. Any time the analysts need data, they can _extract_ it from the DBMS server into a local SQLite database and then _transform_ it in SQLite (or Python or R) prior to analysis. They lose real-time data timeliness, but gain lots of control over way the data is organized.
#
# In order to connect with any database we have to first provide a *connection string* that specifies:
# - what software 'bridge' software is needed
# - where to find the database
# - whatever user credentials are needed to access the data inside the database
#
# For a SQLite database, where there is no concept of user accounts or permissions, the connection string is very simple:
# ```
# sqlite:///<path-to-file>
# ```
# The bridge software is `sqlite` and the location of the database is given by `/<path-to-file>`.
#
# __The code below connects to the `lahman2016.sqlite` database in the same directory as this notebook.__

# %%
# %sql sqlite:///lahman2016.sqlite
# Out:
# 'Connected: @lahman2016.sqlite'

# %% [markdown]
# ## Using SQL to discover the database design
# This can be pretty confusing for SQL newbies. There are no SQL commands for listing all the tables in a database. Instead, we query one or more _metadata_ tables. In SQLite the metadata is in the `sqlite_master` table which describes every data definition object in the database.  Each object has the following fields:
# - `type` -- generally either 'table' or 'index'
# - `name` -- the object name (which is equal to tbl_name if the object is a table)
# - `tbl_name` -- the name of the table that the object describes
# - `rootpage` -- the precise location i the b-tree datastructure used to store the data (for SQLite internal use only)
# - `sql` -- the SQL DDL code needed to create the object

# %%
# %%sql
# /* take a peek at the full sqlite_master table */
# SELECT *
# FROM sqlite_master
# Out:
#  * sqlite:///lahman2016.sqlite
# Done.
# [('table', 'AllstarFull', 'AllstarFull', 2, 'CREATE TABLE AllstarFull (\nplayerID TEXT,\nyearID INTEGER,\ngameNum INTEGER,\ngameID TEXT,\nteamID TEXT,\nlgID TEXT,\nGP INTEGER,\nstartingPos INTEGER\n)'),
#  ('table', 'Appearances', 'Appearances', 3, 'CREATE TABLE Appearances (\nyearID INTEGER,\nteamID TEXT,\nlgID TEXT,\nplayerID TEXT,\nG_all INTEGER,\nGS INTEGER,\nG_batting INTEGER,\nG_defense INT ... (51 characters truncated) ... _2b INTEGER,\nG_3b INTEGER,\nG_ss INTEGER,\nG_lf INTEGER,\nG_cf INTEGER,\nG_rf INTEGER,\nG_of INTEGER,\nG_dh INTEGER,\nG_ph INTEGER,\nG_pr INTEGER\n)'),
#  ('table', 'AwardsManagers', 'AwardsManagers', 4, 'CREATE TABLE AwardsManagers (\nplayerID TEXT,\nawardID TEXT,\nyearID INTEGER,\nlgID TEXT,\ntie TEXT,\nnotes TEXT\n)'),
#  ('table', 'AwardsPlayers', 'AwardsPlayers', 5, 'CREATE TABLE AwardsPlayers (\nplayerID TEXT,\nawardID TEXT,\nyearID INTEGER,\nlgID TEXT,\ntie TEXT,\nnotes TEXT\n)'),
#  ('table', 'AwardsShareManagers', 'AwardsShareManagers', 6, 'CREATE TABLE AwardsShareManagers (\nawardID TEXT,\nyearID INTEGER,\nlgID TEXT,\nplayerID TEXT,\npointsWon INTEGER,\npointsMax INTEGER,\nvotesFirst INTEGER\n)'),
#  ('table', 'AwardsSharePlayers', 'AwardsSharePlayers', 9, 'CREATE TABLE AwardsSharePlayers (\nawardID TEXT,\nyearID INTEGER,\nlgID TEXT,\nplayerID TEXT,\npointsWon REAL,\npointsMax INTEGER,\nvotesFirst REAL\n)'),
#  ('table', 'Batting', 'Batting', 10, 'CREATE TABLE Batting (\nplayerID TEXT,\nyearID INTEGER,\nstint INTEGER,\nteamID TEXT,\nlgID TEXT,\nG INTEGER,\nG_batting INTEGER,\nAB INTEGER,\nR INT ... (64 characters truncated) ... I INTEGER,\nSB INTEGER,\nCS INTEGER,\nBB INTEGER,\nSO INTEGER,\nIBB INTEGER,\nHBP INTEGER,\nSH INTEGER,\nSF INTEGER,\nGIDP INTEGER,\nG_old INTEGER\n)'),
#  ('table', 'BattingPost', 'BattingPost', 11, 'CREATE TABLE BattingPost (\nyearID INTEGER,\nround TEXT,\nplayerID TEXT,\nteamID TEXT,\nlgID TEXT,\nG INTEGER,\nAB INTEGER,\nR INTEGER,\nH INTEGER,\n ... (29 characters truncated) ... nHR INTEGER,\nRBI INTEGER,\nSB INTEGER,\nCS INTEGER,\nBB INTEGER,\nSO INTEGER,\nIBB INTEGER,\nHBP INTEGER,\nSH INTEGER,\nSF INTEGER,\nGIDP INTEGER\n)'),
#  ('table', 'CollegePlaying', 'CollegePlaying', 13, 'CREATE TABLE CollegePlaying (\nplayerID TEXT,\nschoolID TEXT,\nyearID INTEGER\n)'),
#  ('table', 'Fielding', 'Fielding', 14, 'CREATE TABLE Fielding (\nplayerID TEXT,\nyearID INTEGER,\nstint INTEGER,\nteamID TEXT,\nlgID TEXT,\nPOS TEXT,\nG INTEGER,\nGS INTEGER,\nInnOuts INTEGER,\nPO INTEGER,\nA INTEGER,\nE INTEGER,\nDP INTEGER,\nPB INTEGER,\nWP INTEGER,\nSB INTEGER,\nCS INTEGER,\nZR REAL\n)'),
#  ('table', 'FieldingOF', 'FieldingOF', 15, 'CREATE TABLE FieldingOF (\nplayerID TEXT,\nyearID INTEGER,\nstint INTEGER,\nGlf INTEGER,\nGcf INTEGER,\nGrf INTEGER\n)'),
#  ('table', 'FieldingOFsplit', 'FieldingOFsplit', 16, 'CREATE TABLE FieldingOFsplit (\nplayerID TEXT,\nyearID INTEGER,\nstint INTEGER,\nteamID TEXT,\nlgID TEXT,\nPOS TEXT,\nG INTEGER,\nGS INTEGER,\nInnOuts INTEGER,\nPO INTEGER,\nA INTEGER,\nE INTEGER,\nDP INTEGER,\nPB INTEGER,\nWP INTEGER,\nSB INTEGER,\nCS INTEGER,\nZR REAL\n)'),
#  ('table', 'FieldingPost', 'FieldingPost', 18, 'CREATE TABLE FieldingPost (\nplayerID TEXT,\nyearID INTEGER,\nteamID TEXT,\nlgID TEXT,\nround TEXT,\nPOS TEXT,\nG INTEGER,\nGS INTEGER,\nInnOuts INTEGER,\nPO INTEGER,\nA INTEGER,\nE INTEGER,\nDP INTEGER,\nTP INTEGER,\nPB INTEGER,\nSB INTEGER,\nCS INTEGER\n)'),
#  ('table', 'HallOfFame', 'HallOfFame', 19, 'CREATE TABLE HallOfFame (\nplayerID TEXT,\nyearid INTEGER,\nvotedBy TEXT,\nballots INTEGER,\nneeded INTEGER,\nvotes INTEGER,\ninducted TEXT,\ncategory TEXT,\nneeded_note TEXT\n)'),
#  ('table', 'HomeGames', 'HomeGames', 20, 'CREATE TABLE HomeGames (\nyearkey INTEGER,\nleaguekey TEXT,\nteamkey TEXT,\nparkkey TEXT,\nspanfirst TEXT,\nspanlast TEXT,\ngames INTEGER,\nopenings INTEGER,\nattendance INTEGER\n)'),
#  ('table', 'Managers', 'Managers', 21, 'CREATE TABLE Managers (\nplayerID TEXT,\nyearID INTEGER,\nteamID TEXT,\nlgID TEXT,\ninseason INTEGER,\nG INTEGER,\nW INTEGER,\nL INTEGER,\nrank INTEGER,\nplyrMgr TEXT\n)'),
#  ('table', 'ManagersHalf', 'ManagersHalf', 23, 'CREATE TABLE ManagersHalf (\nplayerID TEXT,\nyearID INTEGER,\nteamID TEXT,\nlgID TEXT,\ninseason INTEGER,\nhalf INTEGER,\nG INTEGER,\nW INTEGER,\nL INTEGER,\nrank INTEGER\n)'),
#  ('table', 'Master', 'Master', 24, 'CREATE TABLE Master (\nplayerID TEXT,\nbirthYear INTEGER,\nbirthMonth INTEGER,\nbirthDay INTEGER,\nbirthCountry TEXT,\nbirthState TEXT,\nbirthCity TE ... (141 characters truncated) ... Last TEXT,\nnameGiven TEXT,\nweight INTEGER,\nheight INTEGER,\nbats TEXT,\nthrows TEXT,\ndebut TEXT,\nfinalGame TEXT,\nretroID TEXT,\nbbrefID TEXT\n)'),
#  ('table', 'Parks', 'Parks', 25, 'CREATE TABLE Parks (\nID INTEGER,\nparkalias TEXT,\nparkkey TEXT,\nparkname TEXT,\ncity TEXT,\nstate TEXT,\ncountry TEXT\n)'),
#  ('table', 'Pitching', 'Pitching', 26, 'CREATE TABLE Pitching (\nplayerID TEXT,\nyearID INTEGER,\nstint INTEGER,\nteamID TEXT,\nlgID TEXT,\nW INTEGER,\nL INTEGER,\nG INTEGER,\nGS INTEGER,\n ... (130 characters truncated) ... L,\nERA REAL,\nIBB INTEGER,\nWP INTEGER,\nHBP INTEGER,\nBK INTEGER,\nBFP INTEGER,\nGF INTEGER,\nR INTEGER,\nSH INTEGER,\nSF INTEGER,\nGIDP INTEGER\n)'),
#  ('table', 'PitchingPost', 'PitchingPost', 28, 'CREATE TABLE PitchingPost (\nplayerID TEXT,\nyearID INTEGER,\nround TEXT,\nteamID TEXT,\nlgID TEXT,\nW INTEGER,\nL INTEGER,\nG INTEGER,\nGS INTEGER,\ ... (131 characters truncated) ... L,\nERA REAL,\nIBB INTEGER,\nWP INTEGER,\nHBP INTEGER,\nBK INTEGER,\nBFP INTEGER,\nGF INTEGER,\nR INTEGER,\nSH INTEGER,\nSF INTEGER,\nGIDP INTEGER\n)'),
#  ('table', 'Salaries', 'Salaries', 29, 'CREATE TABLE Salaries (\nyearID INTEGER,\nteamID TEXT,\nlgID TEXT,\nplayerID TEXT,\nsalary REAL\n)'),
#  ('table', 'Schools', 'Schools', 30, 'CREATE TABLE Schools (\nschoolID TEXT,\nname_full TEXT,\ncity TEXT,\nstate TEXT,\ncountry TEXT\n)'),
#  ('table', 'SeriesPost', 'SeriesPost', 32, 'CREATE TABLE SeriesPost (\nyearID INTEGER,\nround TEXT,\nteamIDwinner TEXT,\nlgIDwinner TEXT,\nteamIDloser TEXT,\nlgIDloser TEXT,\nwins INTEGER,\nlosses INTEGER,\nties INTEGER\n)'),
#  ('table', 'Teams', 'Teams', 33, 'CREATE TABLE Teams (\nyearID INTEGER,\nlgID TEXT,\nteamID TEXT,\nfranchID TEXT,\ndivID TEXT,\nRank INTEGER,\nG INTEGER,\nGhome INTEGER,\nW INTEGER,\n ... (389 characters truncated) ... NTEGER,\nFP REAL,\nname TEXT,\npark TEXT,\nattendance INTEGER,\nBPF INTEGER,\nPPF INTEGER,\nteamIDBR TEXT,\nteamIDlahman45 TEXT,\nteamIDretro TEXT\n)'),
#  ('table', 'TeamsFranchises', 'TeamsFranchises', 34, 'CREATE TABLE TeamsFranchises (\nfranchID TEXT,\nfranchName TEXT,\nactive TEXT,\nNAassoc TEXT\n)'),
#  ('table', 'TeamsHalf', 'TeamsHalf', 36, 'CREATE TABLE TeamsHalf (\nyearID INTEGER,\nlgID TEXT,\nteamID TEXT,\nHalf TEXT,\ndivID TEXT,\nDivWin TEXT,\nRank INTEGER,\nG INTEGER,\nW INTEGER,\nL INTEGER\n)'),
#  ('index', 'AllstarFull_gameID', 'AllstarFull', 34282, 'CREATE INDEX AllstarFull_gameID on AllstarFull (gameID)'),
#  ('index', 'AllstarFull_Index_2BD68208_C8B4_4347', 'AllstarFull', 34399, 'CREATE UNIQUE INDEX AllstarFull_Index_2BD68208_C8B4_4347 on AllstarFull (playerID, yearID, gameNum)'),
#  ('index', 'AllstarFull_lgID', 'AllstarFull', 34526, 'CREATE INDEX AllstarFull_lgID on AllstarFull (lgID)'),
#  ('index', 'AllstarFull_teamID', 'AllstarFull', 34584, 'CREATE INDEX AllstarFull_teamID on AllstarFull (teamID)'),
#  ('index', 'Appearances_Index_70924BF9_C76C_4076', 'Appearances', 34648, 'CREATE UNIQUE INDEX Appearances_Index_70924BF9_C76C_4076 on Appearances (yearID, teamID, playerID)'),
#  ('index', 'Appearances_lgID', 'Appearances', 37488, 'CREATE INDEX Appearances_lgID on Appearances (lgID)'),
#  ('index', 'AwardsManagers_Index_5B79AD08_A7C1_426E', 'AwardsManagers', 38729, 'CREATE UNIQUE INDEX AwardsManagers_Index_5B79AD08_A7C1_426E on AwardsManagers (yearID, awardID, lgID, playerID)'),
#  ('index', 'AwardsPlayers_Index_99C7A5A6_27CA_44FC', 'AwardsPlayers', 38739, 'CREATE UNIQUE INDEX AwardsPlayers_Index_99C7A5A6_27CA_44FC on AwardsPlayers (yearID, awardID, lgID, playerID)'),
#  ('index', 'AwardsShareManagers_Index_4D947987_0BEF_4B9B', 'AwardsShareManagers', 39020, 'CREATE UNIQUE INDEX AwardsShareManagers_Index_4D947987_0BEF_4B9B on AwardsShareManagers (awardID, yearID, lgID, playerID)'),
#  ('index', 'AwardsSharePlayers_Index_020E6DB1_95E2_44F1', 'AwardsSharePlayers', 39045, 'CREATE UNIQUE INDEX AwardsSharePlayers_Index_020E6DB1_95E2_44F1 on AwardsSharePlayers (awardID, yearID, lgID, playerID)'),
#  ('index', 'Batting_Index_7170BE9D_268A_46B8', 'Batting', 39272, 'CREATE UNIQUE INDEX Batting_Index_7170BE9D_268A_46B8 on Batting (playerID, yearID, stint)'),
#  ('index', 'Batting_lgID', 'Batting', 41869, 'CREATE INDEX Batting_lgID on Batting (lgID)'),
#  ('index', 'Batting_teamID', 'Batting', 43087, 'CREATE INDEX Batting_teamID on Batting (teamID)'),
#  ('index', 'BattingPost_Index_8C81D106_6E96_4318', 'BattingPost', 44433, 'CREATE UNIQUE INDEX BattingPost_Index_8C81D106_6E96_4318 on BattingPost (yearID, round, playerID)'),
#  ('index', 'BattingPost_lgID', 'BattingPost', 44804, 'CREATE INDEX BattingPost_lgID on BattingPost (lgID)'),
#  ('index', 'BattingPost_teamID', 'BattingPost', 44959, 'CREATE INDEX BattingPost_teamID on BattingPost (teamID)'),
#  ('index', 'Fielding_Index_97751AED_0076_4367', 'Fielding', 45138, 'CREATE UNIQUE INDEX Fielding_Index_97751AED_0076_4367 on Fielding (playerID, yearID, stint, POS)'),
#  ('index', 'Fielding_lgID', 'Fielding', 48986, 'CREATE INDEX Fielding_lgID on Fielding (lgID)'),
#  ('index', 'Fielding_teamID', 'Fielding', 50564, 'CREATE INDEX Fielding_teamID on Fielding (teamID)'),
#  ('index', 'FieldingOF_Index_8983CB74_6371_424E', 'FieldingOF', 52361, 'CREATE UNIQUE INDEX FieldingOF_Index_8983CB74_6371_424E on FieldingOF (playerID, yearID, stint)'),
#  ('index', 'FieldingOFsplit_Index_97751AED_0076_4367', 'FieldingOFsplit', 52657, 'CREATE UNIQUE INDEX FieldingOFsplit_Index_97751AED_0076_4367 on FieldingOFsplit (playerID, yearID, stint, POS)'),
#  ('index', 'FieldingOFsplit_lgID', 'FieldingOFsplit', 53539, 'CREATE INDEX FieldingOFsplit_lgID on FieldingOFsplit (lgID)'),
#  ('index', 'FieldingOFsplit_teamID', 'FieldingOFsplit', 53888, 'CREATE INDEX FieldingOFsplit_teamID on FieldingOFsplit (teamID)'),
#  ('index', 'FieldingPost_Index_E1DA201A_3B38_486D', 'FieldingPost', 54275, 'CREATE UNIQUE INDEX FieldingPost_Index_E1DA201A_3B38_486D on FieldingPost (playerID, yearID, round, POS)'),
#  ('index', 'FieldingPost_lgID', 'FieldingPost', 54660, 'CREATE INDEX FieldingPost_lgID on FieldingPost (lgID)'),
#  ('index', 'FieldingPost_teamID', 'FieldingPost', 54805, 'CREATE INDEX FieldingPost_teamID on FieldingPost (teamID)'),
#  ('index', 'HallOfFame_PrimaryKey', 'HallOfFame', 54966, 'CREATE UNIQUE INDEX HallOfFame_PrimaryKey on HallOfFame (playerID, yearid, votedBy)'),
#  ('index', 'HomeGames_leaguekey', 'HomeGames', 55090, 'CREATE INDEX HomeGames_leaguekey on HomeGames (leaguekey)'),
#  ('index', 'HomeGames_parkkey', 'HomeGames', 55123, 'CREATE INDEX HomeGames_parkkey on HomeGames (parkkey)'),
#  ('index', 'HomeGames_teamkey', 'HomeGames', 55168, 'CREATE INDEX HomeGames_teamkey on HomeGames (teamkey)'),
#  ('index', 'HomeGames_yearkey', 'HomeGames', 55205, 'CREATE INDEX HomeGames_yearkey on HomeGames (yearkey)'),
#  ('index', 'Managers_Index_836DE8E8_FEBD_469A', 'Managers', 55239, 'CREATE UNIQUE INDEX Managers_Index_836DE8E8_FEBD_469A on Managers (yearID, teamID, inseason)'),
#  ('index', 'Managers_lgID', 'Managers', 55302, 'CREATE INDEX Managers_lgID on Managers (lgID)'),
#  ('index', 'Managers_managerID', 'Managers', 55342, 'CREATE INDEX Managers_managerID on Managers (playerID)'),
#  ('index', 'ManagersHalf_Index_C2906EEF_9F52_4968', 'ManagersHalf', 55410, 'CREATE UNIQUE INDEX ManagersHalf_Index_C2906EEF_9F52_4968 on ManagersHalf (yearID, teamID, playerID, half)'),
#  ('index', 'ManagersHalf_lgID', 'ManagersHalf', 55415, 'CREATE INDEX ManagersHalf_lgID on ManagersHalf (lgID)'),
#  ('index', 'Master_bbrefID', 'Master', 55416, 'CREATE INDEX Master_bbrefID on Master (bbrefID)'),
#  ('index', 'Master_playerID', 'Master', 55778, 'CREATE UNIQUE INDEX Master_playerID on Master (playerID)'),
#  ('index', 'Master_retroID', 'Master', 56141, 'CREATE INDEX Master_retroID on Master (retroID)'),
#  ('index', 'Parks_ID', 'Parks', 56484, 'CREATE UNIQUE INDEX Parks_ID on Parks (ID)'),
#  ('index', 'Parks_parkkey', 'Parks', 56488, 'CREATE INDEX Parks_parkkey on Parks (parkkey)'),
#  ('index', 'Pitching_Index_481778A5_18F2_430E', 'Pitching', 56493, 'CREATE UNIQUE INDEX Pitching_Index_481778A5_18F2_430E on Pitching (playerID, yearID, stint)'),
#  ('index', 'Pitching_lgID', 'Pitching', 57606, 'CREATE INDEX Pitching_lgID on Pitching (lgID)'),
#  ('index', 'Pitching_teamID', 'Pitching', 58120, 'CREATE INDEX Pitching_teamID on Pitching (teamID)'),
#  ('index', 'PitchingPost_Index_E71336E6_AB00_432C', 'PitchingPost', 58699, 'CREATE UNIQUE INDEX PitchingPost_Index_E71336E6_AB00_432C on PitchingPost (playerID, yearID, round)'),
#  ('index', 'PitchingPost_lgID', 'PitchingPost', 58844, 'CREATE INDEX PitchingPost_lgID on PitchingPost (lgID)'),
#  ('index', 'PitchingPost_teamID', 'PitchingPost', 58902, 'CREATE INDEX PitchingPost_teamID on PitchingPost (teamID)'),
#  ('index', 'Salaries_Index_E5568031_00FA_49CA', 'Salaries', 58966, 'CREATE UNIQUE INDEX Salaries_Index_E5568031_00FA_49CA on Salaries (yearID, teamID, lgID, playerID)'),
#  ('index', 'Schools_Index_3D308CF0_821E_4DAB', 'Schools', 59767, 'CREATE UNIQUE INDEX Schools_Index_3D308CF0_821E_4DAB on Schools (schoolID)'),
#  ('index', 'SeriesPost_Index_4F4214D5_9891_4F3C', 'SeriesPost', 59789, 'CREATE UNIQUE INDEX SeriesPost_Index_4F4214D5_9891_4F3C on SeriesPost (yearID, round)'),
#  ('index', 'Teams_divID', 'Teams', 59795, 'CREATE INDEX Teams_divID on Teams (divID)'),
#  ('index', 'Teams_franchID', 'Teams', 59823, 'CREATE INDEX Teams_franchID on Teams (franchID)'),
#  ('index', 'Teams_Index_285058F1_D841_4142', 'Teams', 59859, 'CREATE UNIQUE INDEX Teams_Index_285058F1_D841_4142 on Teams (yearID, lgID, teamID)'),
#  ('index', 'TeamsFranchises_Index_D181F923_2BF9_4281', 'TeamsFranchises', 59915, 'CREATE UNIQUE INDEX TeamsFranchises_Index_D181F923_2BF9_4281 on TeamsFranchises (franchID)'),
#  ('index', 'TeamsHalf_divID', 'TeamsHalf', 59918, 'CREATE INDEX TeamsHalf_divID on TeamsHalf (divID)'),
#  ('index', 'TeamsHalf_Index_3FD773F5_2FC0_415C', 'TeamsHalf', 59919, 'CREATE UNIQUE INDEX TeamsHalf_Index_3FD773F5_2FC0_415C on TeamsHalf (yearID, teamID, lgID, Half)')]

# %% [markdown]
# Most of the time we just want to list the table names, like below.

# %%
# %%sql
# SELECT name
# FROM sqlite_master
# WHERE type='table'
# Out:
#  * sqlite:///lahman2016.sqlite
# Done.
# [('AllstarFull',),
#  ('Appearances',),
#  ('AwardsManagers',),
#  ('AwardsPlayers',),
#  ('AwardsShareManagers',),
#  ('AwardsSharePlayers',),
#  ('Batting',),
#  ('BattingPost',),
#  ('CollegePlaying',),
#  ('Fielding',),
#  ('FieldingOF',),
#  ('FieldingOFsplit',),
#  ('FieldingPost',),
#  ('HallOfFame',),
#  ('HomeGames',),
#  ('Managers',),
#  ('ManagersHalf',),
#  ('Master',),
#  ('Parks',),
#  ('Pitching',),
#  ('PitchingPost',),
#  ('Salaries',),
#  ('Schools',),
#  ('SeriesPost',),
#  ('Teams',),
#  ('TeamsFranchises',),
#  ('TeamsHalf',)]

# %% [markdown]
# Of course, if you want to see (candidate) primary keys then you can do that as well, though it takes a little finagling. Can you take this query apart to see how it works?

# %%
# %%sql
# SELECT tbl_name, SUBSTR(sql, INSTR(sql,'(')) AS candidate_key
# FROM sqlite_master
# WHERE type='index' and sql like "CREATE UNIQUE%";
# Out:
#  * sqlite:///lahman2016.sqlite
# Done.
# [('AllstarFull', '(playerID, yearID, gameNum)'),
#  ('Appearances', '(yearID, teamID, playerID)'),
#  ('AwardsManagers', '(yearID, awardID, lgID, playerID)'),
#  ('AwardsPlayers', '(yearID, awardID, lgID, playerID)'),
#  ('AwardsShareManagers', '(awardID, yearID, lgID, playerID)'),
#  ('AwardsSharePlayers', '(awardID, yearID, lgID, playerID)'),
#  ('Batting', '(playerID, yearID, stint)'),
#  ('BattingPost', '(yearID, round, playerID)'),
#  ('Fielding', '(playerID, yearID, stint, POS)'),
#  ('FieldingOF', '(playerID, yearID, stint)'),
#  ('FieldingOFsplit', '(playerID, yearID, stint, POS)'),
#  ('FieldingPost', '(playerID, yearID, round, POS)'),
#  ('HallOfFame', '(playerID, yearid, votedBy)'),
#  ('Managers', '(yearID, teamID, inseason)'),
#  ('ManagersHalf', '(yearID, teamID, playerID, half)'),
#  ('Master', '(playerID)'),
#  ('Parks', '(ID)'),
#  ('Pitching', '(playerID, yearID, stint)'),
#  ('PitchingPost', '(playerID, yearID, round)'),
#  ('Salaries', '(yearID, teamID, lgID, playerID)'),
#  ('Schools', '(schoolID)'),
#  ('SeriesPost', '(yearID, round)'),
#  ('Teams', '(yearID, lgID, teamID)'),
#  ('TeamsFranchises', '(franchID)'),
#  ('TeamsHalf', '(yearID, teamID, lgID, Half)')]

# %% [markdown]
# Tip: Once we have table in mind, we can then also see the CREATE statement that tells us the field definitions.

# %%
# %%sql
# /* the Master table with basic profile data */
# SELECT sql
# FROM sqlite_master
# WHERE type='table' AND name='Master'
# Out:
#  * sqlite:///lahman2016.sqlite
# Done.
# [('CREATE TABLE Master (\nplayerID TEXT,\nbirthYear INTEGER,\nbirthMonth INTEGER,\nbirthDay INTEGER,\nbirthCountry TEXT,\nbirthState TEXT,\nbirthCity TE ... (141 characters truncated) ... Last TEXT,\nnameGiven TEXT,\nweight INTEGER,\nheight INTEGER,\nbats TEXT,\nthrows TEXT,\ndebut TEXT,\nfinalGame TEXT,\nretroID TEXT,\nbbrefID TEXT\n)',)]

# %%
# %%sql
# SELECT sql
# FROM sqlite_master
# WHERE type='table' AND name='HallOfFame'
# Out:
#  * sqlite:///lahman2016.sqlite
# Done.
# [('CREATE TABLE HallOfFame (\nplayerID TEXT,\nyearid INTEGER,\nvotedBy TEXT,\nballots INTEGER,\nneeded INTEGER,\nvotes INTEGER,\ninducted TEXT,\ncategory TEXT,\nneeded_note TEXT\n)',)]

# %% [markdown]
# ## A couple easy queries
# Let's see if we can figure out how this database fits together by exploring a bit.

# %%
# %%sql
# /* Get a list of all Hall of Fame players */
# SELECT nameFirst, nameLast, yearid as induction_year
# FROM HallOfFame
#     JOIN Master USING (playerID)
# WHERE inducted='Y' and category='Player'
# ORDER BY yearid
# Out:
#  * sqlite:///lahman2016.sqlite
# Done.
# [('Ty', 'Cobb', 1936),
#  ('Walter', 'Johnson', 1936),
#  ('Christy', 'Mathewson', 1936),
#  ('Babe', 'Ruth', 1936),
#  ('Honus', 'Wagner', 1936),
#  ('Nap', 'Lajoie', 1937),
#  ('Tris', 'Speaker', 1937),
#  ('Cy', 'Young', 1937),
#  ('Pete', 'Alexander', 1938),
#  ('Cap', 'Anson', 1939),
#  ('Eddie', 'Collins', 1939),
#  ('Buck', 'Ewing', 1939),
#  ('Lou', 'Gehrig', 1939),
#  ('Willie', 'Keeler', 1939),
#  ('Old Hoss', 'Radbourn', 1939),
#  ('George', 'Sisler', 1939),
#  ('Rogers', 'Hornsby', 1942),
#  ('Roger', 'Bresnahan', 1945),
#  ('Dan', 'Brouthers', 1945),
#  ('Fred', 'Clarke', 1945),
#  ('Jimmy', 'Collins', 1945),
#  ('Ed', 'Delahanty', 1945),
#  ('Hugh', 'Duffy', 1945),
#  ('Hughie', 'Jennings', 1945),
#  ('King', 'Kelly', 1945),
#  ('Jim', "O'Rourke", 1945),
#  ('Jesse', 'Burkett', 1946),
#  ('Frank', 'Chance', 1946),
#  ('Jack', 'Chesbro', 1946),
#  ('Johnny', 'Evers', 1946),
#  ('Clark', 'Griffith', 1946),
#  ('Tommy', 'McCarthy', 1946),
#  ('Joe', 'McGinnity', 1946),
#  ('Eddie', 'Plank', 1946),
#  ('Joe', 'Tinker', 1946),
#  ('Rube', 'Waddell', 1946),
#  ('Ed', 'Walsh', 1946),
#  ('Mickey', 'Cochrane', 1947),
#  ('Frankie', 'Frisch', 1947),
#  ('Lefty', 'Grove', 1947),
#  ('Carl', 'Hubbell', 1947),
#  ('Herb', 'Pennock', 1948),
#  ('Pie', 'Traynor', 1948),
#  ('Mordecai', 'Brown', 1949),
#  ('Charlie', 'Gehringer', 1949),
#  ('Kid', 'Nichols', 1949),
#  ('Jimmie', 'Foxx', 1951),
#  ('Mel', 'Ott', 1951),
#  ('Harry', 'Heilmann', 1952),
#  ('Paul', 'Waner', 1952),
#  ('Chief', 'Bender', 1953),
#  ('Dizzy', 'Dean', 1953),
#  ('Al', 'Simmons', 1953),
#  ('Bobby', 'Wallace', 1953),
#  ('Bill', 'Dickey', 1954),
#  ('Rabbit', 'Maranville', 1954),
#  ('Bill', 'Terry', 1954),
#  ('Home Run', 'Baker', 1955),
#  ('Joe', 'DiMaggio', 1955),
#  ('Gabby', 'Hartnett', 1955),
#  ('Ted', 'Lyons', 1955),
#  ('Ray', 'Schalk', 1955),
#  ('Dazzy', 'Vance', 1955),
#  ('Joe', 'Cronin', 1956),
#  ('Hank', 'Greenberg', 1956),
#  ('Sam', 'Crawford', 1957),
#  ('Zack', 'Wheat', 1959),
#  ('Max', 'Carey', 1961),
#  ('Billy', 'Hamilton', 1961),
#  ('Bob', 'Feller', 1962),
#  ('Jackie', 'Robinson', 1962),
#  ('Edd', 'Roush', 1962),
#  ('John', 'Clarkson', 1963),
#  ('Elmer', 'Flick', 1963),
#  ('Sam', 'Rice', 1963),
#  ('Eppa', 'Rixey', 1963),
#  ('Luke', 'Appling', 1964),
#  ('Red', 'Faber', 1964),
#  ('Burleigh', 'Grimes', 1964),
#  ('Tim', 'Keefe', 1964),
#  ('Heinie', 'Manush', 1964),
#  ('John', 'Ward', 1964),
#  ('Pud', 'Galvin', 1965),
#  ('Ted', 'Williams', 1966),
#  ('Red', 'Ruffing', 1967),
#  ('Lloyd', 'Waner', 1967),
#  ('Kiki', 'Cuyler', 1968),
#  ('Goose', 'Goslin', 1968),
#  ('Joe', 'Medwick', 1968),
#  ('Roy', 'Campanella', 1969),
#  ('Stan', 'Coveleski', 1969),
#  ('Waite', 'Hoyt', 1969),
#  ('Stan', 'Musial', 1969),
#  ('Lou', 'Boudreau', 1970),
#  ('Earle', 'Combs', 1970),
#  ('Jesse', 'Haines', 1970),
#  ('Dave', 'Bancroft', 1971),
#  ('Jake', 'Beckley', 1971),
#  ('Chick', 'Hafey', 1971),
#  ('Harry', 'Hooper', 1971),
#  ('Joe', 'Kelley', 1971),
#  ('Rube', 'Marquard', 1971),
#  ('Satchel', 'Paige', 1971),
#  ('Yogi', 'Berra', 1972),
#  ('Josh', 'Gibson', 1972),
#  ('Lefty', 'Gomez', 1972),
#  ('Sandy', 'Koufax', 1972),
#  ('Buck', 'Leonard', 1972),
#  ('Early', 'Wynn', 1972),
#  ('Ross', 'Youngs', 1972),
#  ('Roberto', 'Clemente', 1973),
#  ('Monte', 'Irvin', 1973),
#  ('High Pockets', 'Kelly', 1973),
#  ('Warren', 'Spahn', 1973),
#  ('Mickey', 'Welch', 1973),
#  ('Cool Papa', 'Bell', 1974),
#  ('Jim', 'Bottomley', 1974),
#  ('Whitey', 'Ford', 1974),
#  ('Mickey', 'Mantle', 1974),
#  ('Sam', 'Thompson', 1974),
#  ('Earl', 'Averill', 1975),
#  ('Billy', 'Herman', 1975),
#  ('Judy', 'Johnson', 1975),
#  ('Ralph', 'Kiner', 1975),
#  ('Oscar', 'Charleston', 1976),
#  ('Roger', 'Connor', 1976),
#  ('Bob', 'Lemon', 1976),
#  ('Freddie', 'Lindstrom', 1976),
#  ('Robin', 'Roberts', 1976),
#  ('Ernie', 'Banks', 1977),
#  ('Martin', 'Dihigo', 1977),
#  ('Pop', 'Lloyd', 1977),
#  ('Amos', 'Rusie', 1977),
#  ('Joe', 'Sewell', 1977),
#  ('Addie', 'Joss', 1978),
#  ('Eddie', 'Mathews', 1978),
#  ('Willie', 'Mays', 1979),
#  ('Hack', 'Wilson', 1979),
#  ('Al', 'Kaline', 1980),
#  ('Chuck', 'Klein', 1980),
#  ('Duke', 'Snider', 1980),
#  ('Bob', 'Gibson', 1981),
#  ('Johnny', 'Mize', 1981),
#  ('Hank', 'Aaron', 1982),
#  ('Travis', 'Jackson', 1982),
#  ('Frank', 'Robinson', 1982),
#  ('George', 'Kell', 1983),
#  ('Juan', 'Marichal', 1983),
#  ('Brooks', 'Robinson', 1983),
#  ('Luis', 'Aparicio', 1984),
#  ('Don', 'Drysdale', 1984),
#  ('Rick', 'Ferrell', 1984),
#  ('Harmon', 'Killebrew', 1984),
#  ('Pee Wee', 'Reese', 1984),
#  ('Lou', 'Brock', 1985),
#  ('Enos', 'Slaughter', 1985),
#  ('Arky', 'Vaughan', 1985),
#  ('Hoyt', 'Wilhelm', 1985),
#  ('Bobby', 'Doerr', 1986),
#  ('Ernie', 'Lombardi', 1986),
#  ('Willie', 'McCovey', 1986),
#  ('Ray', 'Dandridge', 1987),
#  ('Catfish', 'Hunter', 1987),
#  ('Billy', 'Williams', 1987),
#  ('Willie', 'Stargell', 1988),
#  ('Johnny', 'Bench', 1989),
#  ('Red', 'Schoendienst', 1989),
#  ('Carl', 'Yastrzemski', 1989),
#  ('Joe', 'Morgan', 1990),
#  ('Jim', 'Palmer', 1990),
#  ('Rod', 'Carew', 1991),
#  ('Fergie', 'Jenkins', 1991),
#  ('Tony', 'Lazzeri', 1991),
#  ('Gaylord', 'Perry', 1991),
#  ('Rollie', 'Fingers', 1992),
#  ('Hal', 'Newhouser', 1992),
#  ('Tom', 'Seaver', 1992),
#  ('Reggie', 'Jackson', 1993),
#  ('Steve', 'Carlton', 1994),
#  ('Phil', 'Rizzuto', 1994),
#  ('Richie', 'Ashburn', 1995),
#  ('Leon', 'Day', 1995),
#  ('Mike', 'Schmidt', 1995),
#  ('Vic', 'Willis', 1995),
#  ('Jim', 'Bunning', 1996),
#  ('Bill', 'Foster', 1996),
#  ('Nellie', 'Fox', 1997),
#  ('Phil', 'Niekro', 1997),
#  ('Willie', 'Wells', 1997),
#  ('George', 'Davis', 1998),
#  ('Larry', 'Doby', 1998),
#  ('Bullet', 'Rogan', 1998),
#  ('Don', 'Sutton', 1998),
#  ('George', 'Brett', 1999),
#  ('Orlando', 'Cepeda', 1999),
#  ('Nolan', 'Ryan', 1999),
#  ('Smokey Joe', 'Williams', 1999),
#  ('Robin', 'Yount', 1999),
#  ('Carlton', 'Fisk', 2000),
#  ('Bid', 'McPhee', 2000),
#  ('Tony', 'Perez', 2000),
#  ('Turkey', 'Stearnes', 2000),
#  ('Bill', 'Mazeroski', 2001),
#  ('Kirby', 'Puckett', 2001),
#  ('Hilton', 'Smith', 2001),
#  ('Dave', 'Winfield', 2001),
#  ('Ozzie', 'Smith', 2002),
#  ('Gary', 'Carter', 2003),
#  ('Eddie', 'Murray', 2003),
#  ('Dennis', 'Eckersley', 2004),
#  ('Paul', 'Molitor', 2004),
#  ('Wade', 'Boggs', 2005),
#  ('Ryne', 'Sandberg', 2005),
#  ('Ray', 'Brown', 2006),
#  ('Willard', 'Brown', 2006),
#  ('Andy', 'Cooper', 2006),
#  ('Frank', 'Grant', 2006),
#  ('Pete', 'Hill', 2006),
#  ('Biz', 'Mackey', 2006),
#  ('Jose', 'Mendez', 2006),
#  ('Louis', 'Santop', 2006),
#  ('Bruce', 'Sutter', 2006),
#  ('Mule', 'Suttles', 2006),
#  ('Ben', 'Taylor', 2006),
#  ('Cristobal', 'Torriente', 2006),
#  ('Jud', 'Wilson', 2006),
#  ('Tony', 'Gwynn', 2007),
#  ('Cal', 'Ripken', 2007),
#  ('Rich', 'Gossage', 2008),
#  ('Joe', 'Gordon', 2009),
#  ('Rickey', 'Henderson', 2009),
#  ('Jim', 'Rice', 2009),
#  ('Andre', 'Dawson', 2010),
#  ('Roberto', 'Alomar', 2011),
#  ('Bert', 'Blyleven', 2011),
#  ('Barry', 'Larkin', 2012),
#  ('Ron', 'Santo', 2012),
#  ('Deacon', 'White', 2013),
#  ('Tom', 'Glavine', 2014),
#  ('Greg', 'Maddux', 2014),
#  ('Frank', 'Thomas', 2014),
#  ('Craig', 'Biggio', 2015),
#  ('Randy', 'Johnson', 2015),
#  ('Pedro', 'Martinez', 2015),
#  ('John', 'Smoltz', 2015),
#  ('Ken', 'Griffey', 2016),
#  ('Mike', 'Piazza', 2016),
#  ('Jeff', 'Bagwell', 2017),
#  ('Tim', 'Raines', 2017),
#  ('Ivan', 'Rodriguez', 2017)]

# %%
# %%sql
# /* add in the number of all star games each HoF player played */
# SELECT nameFirst, nameLast, HallOfFame.yearid as induction_year,count(AllstarFull.yearID) AS allstar_appearances
# FROM HallOfFame
#     JOIN Master USING (playerID)
#     LEFT JOIN AllstarFull USING (playerID)
# WHERE inducted='Y' and category='Player'
# GROUP BY playerID, nameFirst, nameLast
# ORDER BY allstar_appearances DESC
# Out:
#  * sqlite:///lahman2016.sqlite
# Done.
# [('Hank', 'Aaron', 1982, 25),
#  ('Willie', 'Mays', 1979, 24),
#  ('Stan', 'Musial', 1969, 24),
#  ('Mickey', 'Mantle', 1974, 20),
#  ('Cal', 'Ripken', 2007, 19),
#  ('Ted', 'Williams', 1966, 19),
#  ('Yogi', 'Berra', 1972, 18),
#  ('Rod', 'Carew', 1991, 18),
#  ('Al', 'Kaline', 1980, 18),
#  ('Brooks', 'Robinson', 1983, 18),
#  ('Carl', 'Yastrzemski', 1989, 18),
#  ('Warren', 'Spahn', 1973, 17),
#  ('Roberto', 'Clemente', 1973, 15),
#  ('Nellie', 'Fox', 1997, 15),
#  ('Tony', 'Gwynn', 2007, 15),
#  ('Ozzie', 'Smith', 2002, 15),
#  ('Ernie', 'Banks', 1977, 14),
#  ('Johnny', 'Bench', 1989, 14),
#  ('Reggie', 'Jackson', 1993, 14),
#  ('Frank', 'Robinson', 1982, 14),
#  ('Ivan', 'Rodriguez', 2017, 14),
#  ('Luis', 'Aparicio', 1984, 13),
#  ('George', 'Brett', 1999, 13),
#  ('Joe', 'DiMaggio', 1955, 13),
#  ('Ken', 'Griffey', 2016, 13),
#  ('Harmon', 'Killebrew', 1984, 13),
#  ('Roberto', 'Alomar', 2011, 12),
#  ('Wade', 'Boggs', 2005, 12),
#  ('Barry', 'Larkin', 2012, 12),
#  ('Eddie', 'Mathews', 1978, 12),
#  ('Mel', 'Ott', 1951, 12),
#  ('Mike', 'Piazza', 2016, 12),
#  ('Mike', 'Schmidt', 1995, 12),
#  ('Tom', 'Seaver', 1992, 12),
#  ('Dave', 'Winfield', 2001, 12),
#  ('Gary', 'Carter', 2003, 11),
#  ('Orlando', 'Cepeda', 1999, 11),
#  ('Bill', 'Dickey', 1954, 11),
#  ('Carlton', 'Fisk', 2000, 11),
#  ('Steve', 'Carlton', 1994, 10),
#  ('Whitey', 'Ford', 1974, 10),
#  ('Tom', 'Glavine', 2014, 10),
#  ('Rickey', 'Henderson', 2009, 10),
#  ('Billy', 'Herman', 1975, 10),
#  ('Randy', 'Johnson', 2015, 10),
#  ('George', 'Kell', 1983, 10),
#  ('Juan', 'Marichal', 1983, 10),
#  ('Bill', 'Mazeroski', 2001, 10),
#  ('Joe', 'Medwick', 1968, 10),
#  ('Johnny', 'Mize', 1981, 10),
#  ('Joe', 'Morgan', 1990, 10),
#  ('Kirby', 'Puckett', 2001, 10),
#  ('Pee Wee', 'Reese', 1984, 10),
#  ('Ryne', 'Sandberg', 2005, 10),
#  ('Red', 'Schoendienst', 1989, 10),
#  ('Enos', 'Slaughter', 1985, 10),
#  ('Jim', 'Bunning', 1996, 9),
#  ('Bobby', 'Doerr', 1986, 9),
#  ('Don', 'Drysdale', 1984, 9),
#  ('Jimmie', 'Foxx', 1951, 9),
#  ('Bob', 'Gibson', 1981, 9),
#  ('Joe', 'Gordon', 2009, 9),
#  ('Rich', 'Gossage', 2008, 9),
#  ('Carl', 'Hubbell', 1947, 9),
#  ('Ron', 'Santo', 2012, 9),
#  ('Arky', 'Vaughan', 1985, 9),
#  ('Lou', 'Boudreau', 1970, 8),
#  ('Roy', 'Campanella', 1969, 8),
#  ('Andre', 'Dawson', 2010, 8),
#  ('Bob', 'Feller', 1962, 8),
#  ('Rick', 'Ferrell', 1984, 8),
#  ('Catfish', 'Hunter', 1987, 8),
#  ('Ernie', 'Lombardi', 1986, 8),
#  ('Greg', 'Maddux', 2014, 8),
#  ('Pedro', 'Martinez', 2015, 8),
#  ('Eddie', 'Murray', 2003, 8),
#  ('Jim', 'Rice', 2009, 8),
#  ('Nolan', 'Ryan', 1999, 8),
#  ('John', 'Smoltz', 2015, 8),
#  ('Duke', 'Snider', 1980, 8),
#  ('Hoyt', 'Wilhelm', 1985, 8),
#  ('Early', 'Wynn', 1972, 8),
#  ('Luke', 'Appling', 1964, 7),
#  ('Craig', 'Biggio', 2015, 7),
#  ('Joe', 'Cronin', 1956, 7),
#  ('Larry', 'Doby', 1998, 7),
#  ('Rollie', 'Fingers', 1992, 7),
#  ('Lou', 'Gehrig', 1939, 7),
#  ('Lefty', 'Gomez', 1972, 7),
#  ('Sandy', 'Koufax', 1972, 7),
#  ('Bob', 'Lemon', 1976, 7),
#  ('Paul', 'Molitor', 2004, 7),
#  ('Hal', 'Newhouser', 1992, 7),
#  ('Tony', 'Perez', 2000, 7),
#  ('Tim', 'Raines', 2017, 7),
#  ('Robin', 'Roberts', 1976, 7),
#  ('Willie', 'Stargell', 1988, 7),
#  ('Richie', 'Ashburn', 1995, 6),
#  ('Earl', 'Averill', 1975, 6),
#  ('Lou', 'Brock', 1985, 6),
#  ('Dennis', 'Eckersley', 2004, 6),
#  ('Charlie', 'Gehringer', 1949, 6),
#  ('Lefty', 'Grove', 1947, 6),
#  ('Gabby', 'Hartnett', 1955, 6),
#  ('Ralph', 'Kiner', 1975, 6),
#  ('Willie', 'McCovey', 1986, 6),
#  ('Jim', 'Palmer', 1990, 6),
#  ('Jackie', 'Robinson', 1962, 6),
#  ('Red', 'Ruffing', 1967, 6),
#  ('Bruce', 'Sutter', 2006, 6),
#  ('Billy', 'Williams', 1987, 6),
#  ('Hank', 'Greenberg', 1956, 5),
#  ('Phil', 'Niekro', 1997, 5),
#  ('Gaylord', 'Perry', 1991, 5),
#  ('Phil', 'Rizzuto', 1994, 5),
#  ('Frank', 'Thomas', 2014, 5),
#  ('Jeff', 'Bagwell', 2017, 4),
#  ('Dizzy', 'Dean', 1953, 4),
#  ('Don', 'Sutton', 1998, 4),
#  ('Paul', 'Waner', 1952, 4),
#  ('Frankie', 'Frisch', 1947, 3),
#  ('Fergie', 'Jenkins', 1991, 3),
#  ('Al', 'Simmons', 1953, 3),
#  ('Bill', 'Terry', 1954, 3),
#  ('Robin', 'Yount', 1999, 3),
#  ('Bert', 'Blyleven', 2011, 2),
#  ('Mickey', 'Cochrane', 1947, 2),
#  ('Chuck', 'Klein', 1980, 2),
#  ('Satchel', 'Paige', 1971, 2),
#  ('Babe', 'Ruth', 1936, 2),
#  ('Pie', 'Traynor', 1948, 2),
#  ('Kiki', 'Cuyler', 1968, 1),
#  ('Goose', 'Goslin', 1968, 1),
#  ('Chick', 'Hafey', 1971, 1),
#  ('Monte', 'Irvin', 1973, 1),
#  ('Travis', 'Jackson', 1982, 1),
#  ('Tony', 'Lazzeri', 1991, 1),
#  ('Ted', 'Lyons', 1955, 1),
#  ('Heinie', 'Manush', 1964, 1),
#  ('Lloyd', 'Waner', 1967, 1),
#  ('Pete', 'Alexander', 1938, 0),
#  ('Cap', 'Anson', 1939, 0),
#  ('Home Run', 'Baker', 1955, 0),
#  ('Dave', 'Bancroft', 1971, 0),
#  ('Jake', 'Beckley', 1971, 0),
#  ('Cool Papa', 'Bell', 1974, 0),
#  ('Chief', 'Bender', 1953, 0),
#  ('Jim', 'Bottomley', 1974, 0),
#  ('Roger', 'Bresnahan', 1945, 0),
#  ('Dan', 'Brouthers', 1945, 0),
#  ('Mordecai', 'Brown', 1949, 0),
#  ('Ray', 'Brown', 2006, 0),
#  ('Willard', 'Brown', 2006, 0),
#  ('Jesse', 'Burkett', 1946, 0),
#  ('Max', 'Carey', 1961, 0),
#  ('Frank', 'Chance', 1946, 0),
#  ('Oscar', 'Charleston', 1976, 0),
#  ('Jack', 'Chesbro', 1946, 0),
#  ('Fred', 'Clarke', 1945, 0),
#  ('John', 'Clarkson', 1963, 0),
#  ('Ty', 'Cobb', 1936, 0),
#  ('Eddie', 'Collins', 1939, 0),
#  ('Jimmy', 'Collins', 1945, 0),
#  ('Earle', 'Combs', 1970, 0),
#  ('Roger', 'Connor', 1976, 0),
#  ('Andy', 'Cooper', 2006, 0),
#  ('Stan', 'Coveleski', 1969, 0),
#  ('Sam', 'Crawford', 1957, 0),
#  ('Ray', 'Dandridge', 1987, 0),
#  ('George', 'Davis', 1998, 0),
#  ('Leon', 'Day', 1995, 0),
#  ('Ed', 'Delahanty', 1945, 0),
#  ('Martin', 'Dihigo', 1977, 0),
#  ('Hugh', 'Duffy', 1945, 0),
#  ('Johnny', 'Evers', 1946, 0),
#  ('Buck', 'Ewing', 1939, 0),
#  ('Red', 'Faber', 1964, 0),
#  ('Elmer', 'Flick', 1963, 0),
#  ('Bill', 'Foster', 1996, 0),
#  ('Pud', 'Galvin', 1965, 0),
#  ('Josh', 'Gibson', 1972, 0),
#  ('Frank', 'Grant', 2006, 0),
#  ('Clark', 'Griffith', 1946, 0),
#  ('Burleigh', 'Grimes', 1964, 0),
#  ('Jesse', 'Haines', 1970, 0),
#  ('Billy', 'Hamilton', 1961, 0),
#  ('Harry', 'Heilmann', 1952, 0),
#  ('Pete', 'Hill', 2006, 0),
#  ('Harry', 'Hooper', 1971, 0),
#  ('Rogers', 'Hornsby', 1942, 0),
#  ('Waite', 'Hoyt', 1969, 0),
#  ('Hughie', 'Jennings', 1945, 0),
#  ('Judy', 'Johnson', 1975, 0),
#  ('Walter', 'Johnson', 1936, 0),
#  ('Addie', 'Joss', 1978, 0),
#  ('Tim', 'Keefe', 1964, 0),
#  ('Willie', 'Keeler', 1939, 0),
#  ('Joe', 'Kelley', 1971, 0),
#  ('High Pockets', 'Kelly', 1973, 0),
#  ('King', 'Kelly', 1945, 0),
#  ('Nap', 'Lajoie', 1937, 0),
#  ('Buck', 'Leonard', 1972, 0),
#  ('Freddie', 'Lindstrom', 1976, 0),
#  ('Pop', 'Lloyd', 1977, 0),
#  ('Biz', 'Mackey', 2006, 0),
#  ('Rabbit', 'Maranville', 1954, 0),
#  ('Rube', 'Marquard', 1971, 0),
#  ('Christy', 'Mathewson', 1936, 0),
#  ('Tommy', 'McCarthy', 1946, 0),
#  ('Joe', 'McGinnity', 1946, 0),
#  ('Bid', 'McPhee', 2000, 0),
#  ('Jose', 'Mendez', 2006, 0),
#  ('Kid', 'Nichols', 1949, 0),
#  ('Jim', "O'Rourke", 1945, 0),
#  ('Herb', 'Pennock', 1948, 0),
#  ('Eddie', 'Plank', 1946, 0),
#  ('Old Hoss', 'Radbourn', 1939, 0),
#  ('Sam', 'Rice', 1963, 0),
#  ('Eppa', 'Rixey', 1963, 0),
#  ('Bullet', 'Rogan', 1998, 0),
#  ('Edd', 'Roush', 1962, 0),
#  ('Amos', 'Rusie', 1977, 0),
#  ('Louis', 'Santop', 2006, 0),
#  ('Ray', 'Schalk', 1955, 0),
#  ('Joe', 'Sewell', 1977, 0),
#  ('George', 'Sisler', 1939, 0),
#  ('Hilton', 'Smith', 2001, 0),
#  ('Tris', 'Speaker', 1937, 0),
#  ('Turkey', 'Stearnes', 2000, 0),
#  ('Mule', 'Suttles', 2006, 0),
#  ('Ben', 'Taylor', 2006, 0),
#  ('Sam', 'Thompson', 1974, 0),
#  ('Joe', 'Tinker', 1946, 0),
#  ('Cristobal', 'Torriente', 2006, 0),
#  ('Dazzy', 'Vance', 1955, 0),
#  ('Rube', 'Waddell', 1946, 0),
#  ('Honus', 'Wagner', 1936, 0),
#  ('Bobby', 'Wallace', 1953, 0),
#  ('Ed', 'Walsh', 1946, 0),
#  ('John', 'Ward', 1964, 0),
#  ('Mickey', 'Welch', 1973, 0),
#  ('Willie', 'Wells', 1997, 0),
#  ('Zack', 'Wheat', 1959, 0),
#  ('Deacon', 'White', 2013, 0),
#  ('Smokey Joe', 'Williams', 1999, 0),
#  ('Vic', 'Willis', 1995, 0),
#  ('Hack', 'Wilson', 1979, 0),
#  ('Jud', 'Wilson', 2006, 0),
#  ('Cy', 'Young', 1937, 0),
#  ('Ross', 'Youngs', 1972, 0)]

# %% [markdown]
# ## (Optional) Python Integration Tips
# This section is for those of you using this database in your other classes. If you don't know or care about Python then please skip. However, if you subsequently take a Python class with databases, then perhaps you might like to come back then.

# %% [markdown]
# ### You can embed SQL code directly into your Python code without SqlAlchemy

# %%
import pandas as pd
 
parks = %sql SELECT parkname, city, state, country FROM Parks
parks # parks is a resultset object that is mostly compatible with a dataframe
# Out:
#  * sqlite:///lahman2016.sqlite
# Done.
# [('Candlestick Park', 'San Francisco', 'CA', 'US'),
#  ('AT&T Park', 'San Francisco', 'CA', 'US'),
#  ('Estadio Hiram Bithorn', 'San Juan', None, 'PR'),
#  ('Hampden Park Race Track', 'Springfield', 'MA', 'US'),
#  ('Red Stockings Base Ball Park', 'St. Louis', 'MO', 'US'),
#  ('Grand Avenue Park', 'St. Louis', 'MO', 'US'),
#  ("Sportsman's Park I", 'St. Louis', 'MO', 'US'),
#  ('Union Grounds', 'St. Louis', 'MO', 'US'),
#  ('Robison Field', 'St. Louis', 'MO', 'US'),
#  ("Sportsman's Park II", 'St. Louis', 'MO', 'US'),
#  ("Sportsman's Park III", 'St. Louis', 'MO', 'US'),
#  ("Handlan's Park", 'St. Louis', 'MO', 'US'),
#  ('Busch Stadium II', 'St. Louis', 'MO', 'US'),
#  ('Busch Stadium III', 'St. Louis', 'MO', 'US'),
#  ('Tropicana Field', 'St. Petersburg', 'FL', 'US'),
#  ('Sydney Cricket Ground', 'Sydney', 'New South Wales', 'AU'),
#  ('Star Park I', 'Syracuse', 'NY', 'US'),
#  ('Star Park II', 'Syracuse', 'NY', 'US'),
#  ('Iron Pier', 'Syracuse', 'NY', 'US'),
#  ('Three Rivers Park', 'Three Rivers', 'NY', 'US'),
#  ('Tokyo Dome', 'Tokyo', 'Tokyo', 'JP'),
#  ('League Park', 'Toledo', 'OH', 'US'),
#  ('Tri-State Fair Grounds', 'Toledo', 'OH', 'US'),
#  ('Speranza Park', 'Toledo', 'OH', 'US'),
#  ('Armory Park', 'Toledo', 'OH', 'US'),
#  ('Exhibition Stadium', 'Toronto', 'ON', 'CA'),
#  ('Rogers Centre', 'Toronto', 'ON', 'CA'),
#  ("Haymakers' Grounds", 'Troy', 'NY', 'US'),
#  ('Putnam Grounds', 'Troy', 'NY', 'US'),
#  ('Rocky Point Park', 'Warwick', 'RI', 'US'),
#  ('Olympic Grounds', 'Washington', 'DC', 'US'),
#  ('National Grounds', 'Washington', 'DC', 'US'),
#  ('Capitol Grounds', 'Washington', 'DC', 'US'),
#  ('Athletic Park', 'Washington', 'DC', 'US'),
#  ('Swampoodle Grounds', 'Washington', 'DC', 'US'),
#  ('Boundary Field', 'Washington', 'DC', 'US'),
#  ('American League Park I', 'Washington', 'DC', 'US'),
#  ('American League Park II', 'Washington', 'DC', 'US'),
#  ('Griffith Stadium', 'Washington', 'DC', 'US'),
#  ('Robert F. Kennedy Stadium', 'Washington', 'DC', 'US'),
#  ('Nationals Park', 'Washington', 'DC', 'US'),
#  ('Troy Ball Club Grounds', 'Watervliet', 'NY', 'US'),
#  ('Waverly Fairgrounds', 'Waverly', 'NJ', 'US'),
#  ('Monitor Grounds', 'Weehawken', 'NJ', 'US'),
#  ('Island Grounds', 'Wheeling', 'WV', 'US'),
#  ('Union Street Park', 'Wilmington', 'DE', 'US'),
#  ('West New York Field Club Grounds', 'West New York', 'NJ', 'US'),
#  ('Agricultural County Fair Grounds I', 'Worcester', 'MA', 'US'),
#  ('Agricultural County Fair Grounds II', 'Worcester', 'MA', 'US'),
#  ('Worcester Driving Park Grounds', 'Worcester', 'MA', 'US'),
#  ('Riverside Park', 'Albany', 'NY', 'US'),
#  ('Columbia Park', 'Altoona', 'PA', 'US'),
#  ('Angel Stadium of Anaheim', 'Anaheim', 'CA', 'US'),
#  ('Arlington Stadium', 'Arlington', 'TX', 'US'),
#  ('Rangers Ballpark in Arlington', 'Arlington', 'TX', 'US'),
#  ('Atlanta-Fulton County Stadium', 'Atlanta', 'GA', 'US'),
#  ('Turner Field', 'Atlanta', 'GA', 'US'),
#  ('Madison Avenue Grounds', 'Baltimore', 'MD', 'US'),
#  ('Newington Park', 'Baltimore', 'MD', 'US'),
#  ('Oriole Park I', 'Baltimore', 'MD', 'US'),
#  ('Belair Lot', 'Baltimore', 'MD', 'US'),
#  ('Monumental Park', 'Baltimore', 'MD', 'US'),
#  ('Oriole Park II', 'Baltimore', 'MD', 'US'),
#  ('Oriole Park III', 'Baltimore', 'MD', 'US'),
#  ('Oriole Park IV', 'Baltimore', 'MD', 'US'),
#  ('Terrapin Park', 'Baltimore', 'MD', 'US'),
#  ('Memorial Stadium', 'Baltimore', 'MD', 'US'),
#  ('Oriole Park at Camden Yards', 'Baltimore', 'MD', 'US'),
#  ('South End Grounds I', 'Boston', 'MA', 'US'),
#  ('Dartmouth Grounds', 'Boston', 'MA', 'US'),
#  ('South End Grounds II', 'Boston', 'MA', 'US'),
#  ('Congress Street Grounds', 'Boston', 'MA', 'US'),
#  ('South End Grounds III', 'Boston', 'MA', 'US'),
#  ('Huntington Avenue Baseball Grounds', 'Boston', 'MA', 'US'),
#  ('Fenway Park', 'Boston', 'MA', 'US'),
#  ('Braves Field', 'Boston', 'MA', 'US'),
#  ('Riverside Grounds', 'Buffalo', 'NY', 'US'),
#  ('Olympic Park I', 'Buffalo', 'NY', 'US'),
#  ('Olympic Park II', 'Buffalo', 'NY', 'US'),
#  ('International Fair Association Grounds', 'Buffalo', 'NY', 'US'),
#  ('Mahaffey Park', 'Canton', 'OH', 'US'),
#  ('Pastime Park', 'Canton', 'OH', 'US'),
#  ('Lake Front Park I', 'Chicago', 'IL', 'US'),
#  ('23rd Street Park', 'Chicago', 'IL', 'US'),
#  ('Lake Front Park II', 'Chicago', 'IL', 'US'),
#  ('Lake Front Park III', 'Chicago', 'IL', 'US'),
#  ('South Side Park I', 'Chicago', 'IL', 'US'),
#  ('West Side Park', 'Chicago', 'IL', 'US'),
#  ('South Side Park II', 'Chicago', 'IL', 'US'),
#  ('West Side Grounds', 'Chicago', 'IL', 'US'),
#  ('South Side Park III', 'Chicago', 'IL', 'US'),
#  ('Comiskey Park I', 'Chicago', 'IL', 'US'),
#  ('Wrigley Field', 'Chicago', 'IL', 'US'),
#  ('U.S. Cellular Field', 'Chicago', 'IL', 'US'),
#  ('Lincoln Park Grounds', 'Cincinnati', 'OH', 'US'),
#  ('Avenue Grounds', 'Cincinnati', 'OH', 'US'),
#  ('Bank Street Grounds', 'Cincinnati', 'OH', 'US'),
#  ('League Park I', 'Cincinnati', 'OH', 'US'),
#  ('League Park II', 'Cincinnati', 'OH', 'US'),
#  ('Palace of the Fans', 'Cincinnati', 'OH', 'US'),
#  ('Crosley Field', 'Cincinnati', 'OH', 'US'),
#  ('Cinergy Field', 'Cincinnati', 'OH', 'US'),
#  ('Great American Ballpark', 'Cincinnati', 'OH', 'US'),
#  ('National Association Grounds', 'Cleveland', 'OH', 'US'),
#  ('League Park I', 'Cleveland', 'OH', 'US'),
#  ('League Park II', 'Cleveland', 'OH', 'US'),
#  ('Brotherhood Park', 'Cleveland', 'OH', 'US'),
#  ('League Park III', 'Cleveland', 'OH', 'US'),
#  ('League Park IV', 'Cleveland', 'OH', 'US'),
#  ('Cleveland Stadium', 'Cleveland', 'OH', 'US'),
#  ('Progressive Field', 'Cleveland', 'OH', 'US'),
#  ('Cedar Avenue Driving Park', 'Cleveland', 'OH', 'US'),
#  ('Euclid Beach Park', 'Collinwood', 'OH', 'US'),
#  ('Recreation Park I', 'Columbus', 'OH', 'US'),
#  ('Recreation Park II', 'Columbus', 'OH', 'US'),
#  ('Neil Park I', 'Columbus', 'OH', 'US'),
#  ('Neil Park II', 'Columbus', 'OH', 'US'),
#  ('Star Baseball Park', 'Covington', 'KY', 'US'),
#  ('Fairview Park', 'Dayton', 'OH', 'US'),
#  ('Mile High Stadium', 'Denver', 'CO', 'US'),
#  ('Coors Field', 'Denver', 'CO', 'US'),
#  ('Recreation Park', 'Detroit', 'MI', 'US'),
#  ('Bennett Park', 'Detroit', 'MI', 'US'),
#  ('Burns Park', 'Detroit', 'MI', 'US'),
#  ('Tiger Stadium', 'Detroit', 'MI', 'US'),
#  ('Comerica Park', 'Detroit', 'MI', 'US'),
#  ('Fairview Park Fair Grounds', 'Dover', 'DE', 'US'),
#  ('Maple Avenue Driving Park', 'Elmira', 'NY', 'US'),
#  ('Grand Duchess', 'Fort Wayne', 'IN', 'US'),
#  ('Swinney Park', 'Fort Wayne', 'IN', 'US'),
#  ('Jailhouse Flats', 'Fort Wayne', 'IN', 'US'),
#  ('Geauga Lake Grounds', 'Geauga Lake', 'OH', 'US'),
#  ('Gloucester Point Grounds', 'Gloucester City', 'NJ', 'US'),
#  ('Ramona Park', 'Grand Rapids', 'MI', 'US'),
#  ('Harrison Field', 'Harrison', 'NJ', 'US'),
#  ('Aloha Stadium', 'Honolulu', 'HI', 'US'),
#  ('Colt Stadium', 'Houston', 'TX', 'US'),
#  ('Astrodome', 'Houston', 'TX', 'US'),
#  ('Minute Maid Park', 'Houston', 'TX', 'US'),
#  ('Hartford Ball Club Grounds', 'Hartford', 'CT', 'US'),
#  ('Hartford Trotting Park', 'Hartford', 'CT', 'US'),
#  ('South Street Park', 'Indianapolis', 'IN', 'US'),
#  ('Seventh Street Park I', 'Indianapolis', 'IN', 'US'),
#  ('Bruce Grounds', 'Indianapolis', 'IN', 'US'),
#  ('Seventh Street Park II', 'Indianapolis', 'IN', 'US'),
#  ('Seventh Street Park III', 'Indianapolis', 'IN', 'US'),
#  ('Indianapolis Park', 'Indianapolis', 'IN', 'US'),
#  ('Federal League Park', 'Indianapolis', 'IN', 'US'),
#  ('Windsor Beach', 'Irondequoit', 'NY', 'US'),
#  ('Oakland Park', 'Jersey City', 'NJ', 'US'),
#  ('Roosevelt Stadium', 'Jersey City', 'NJ', 'US'),
#  ('Athletic Park', 'Kansas City', 'MO', 'US'),
#  ('Association Park', 'Kansas City', 'MO', 'US'),
#  ('Exposition Park', 'Kansas City', 'MO', 'US'),
#  ('Gordon and Koppel Field', 'Kansas City', 'MO', 'US'),
#  ('Municipal Stadium', 'Kansas City', 'MO', 'US'),
#  ('Kauffman Stadium', 'Kansas City', 'MO', 'US'),
#  ('Perry Park', 'Keokuk', 'IA', 'US'),
#  ('Cashman Field', 'Las Vegas', 'NV', 'US'),
#  ("The Ballpark at Disney's Wide World", 'Lake Buena Vista', 'FL', 'US'),
#  ('Los Angeles Memorial Coliseum', 'Los Angeles', 'CA', 'US'),
#  ('Wrigley Field', 'Los Angeles', 'CA', 'US'),
#  ('Dodger Stadium', 'Los Angeles', 'CA', 'US'),
#  ('Louisville Baseball Park', 'Louisville', 'KY', 'US'),
#  ('Eclipse Park I', 'Louisville', 'KY', 'US'),
#  ('Eclipse Park II', 'Louisville', 'KY', 'US'),
#  ('Eclipse Park III', 'Louisville', 'KY', 'US'),
#  ('Ludlow Baseball Park', 'Ludlow', 'KY', 'US'),
#  ('Long Island Grounds', 'Maspeth', 'NY', 'US'),
#  ('Sun Life Stadium', 'Miami', 'FL', 'US'),
#  ('Marlins Park', 'Miami', 'FL', 'US'),
#  ('Mansfield Club Grounds', 'Middletown', 'CT', 'US'),
#  ('Milwaukee Base-Ball Grounds', 'Milwaukee', 'WI', 'US'),
#  ('Wright Street Grounds', 'Milwaukee', 'WI', 'US'),
#  ('Athletic Park', 'Milwaukee', 'WI', 'US'),
#  ('Lloyd Street Grounds', 'Milwaukee', 'WI', 'US'),
#  ('County Stadium', 'Milwaukee', 'WI', 'US'),
#  ('Miller Park', 'Milwaukee', 'WI', 'US'),
#  ('Athletic Park', 'Minneapolis', 'MN', 'US'),
#  ('Metropolitan Stadium', 'Bloomington', 'MN', 'US'),
#  ('Hubert H. Humphrey Metrodome', 'Minneapolis', 'MN', 'US'),
#  ('Target Field', 'Minneapolis', 'MN', 'US'),
#  ('Estadio Monterrey', 'Monterrey', 'Nuevo Leon', 'MX'),
#  ('Parc Jarry', 'Montreal', 'QC', 'CA'),
#  ('Stade Olympique', 'Montreal', 'QC', 'CA'),
#  ('Howard Avenue Grounds', 'New Haven', 'CT', 'US'),
#  ('Hamilton Park', 'New Haven', 'CT', 'US'),
#  ("Beyerle's Park", 'Newburgh Township', 'OH', 'US'),
#  ("Wiedenmeyer's Park", 'Newark', 'NJ', 'US'),
#  ('Union Grounds', 'Brooklyn', 'NY', 'US'),
#  ('Capitoline Grounds', 'Brooklyn', 'NY', 'US'),
#  ('Polo Grounds I (Southeast Diamond)', 'New York', 'NY', 'US'),
#  ('Polo Grounds II (Southwest Diamond)', 'New York', 'NY', 'US'),
#  ('Washington Park I', 'Brooklyn', 'NY', 'US'),
#  ('Metropolitan Park', 'New York', 'NY', 'US'),
#  ("Grauer's Ridgewood Park", 'Queens', 'NY', 'US'),
#  ('Washington Park II', 'Brooklyn', 'NY', 'US'),
#  ('Polo Grounds III', 'New York', 'NY', 'US'),
#  ('Polo Grounds IV', 'New York', 'NY', 'US'),
#  ('Eastern Park', 'Brooklyn', 'NY', 'US'),
#  ('Washington Park III', 'Brooklyn', 'NY', 'US'),
#  ('Hilltop Park', 'New York', 'NY', 'US'),
#  ('Polo Grounds V', 'New York', 'NY', 'US'),
#  ('Ebbets Field', 'Brooklyn', 'NY', 'US'),
#  ('Yankee Stadium I', 'New York', 'NY', 'US'),
#  ('Shea Stadium', 'New York', 'NY', 'US'),
#  ("Wallace's Ridgewood Park", 'Queens', 'NY', 'US'),
#  ('Washington Park IV', 'Brooklyn', 'NY', 'US'),
#  ('Citi Field', 'New York', 'NY', 'US'),
#  ('Yankee Stadium II', 'New York', 'NY', 'US'),
#  ('Oakland-Alameda County Coliseum', 'Oakland', 'CA', 'US'),
#  ('East End Park', 'Cincinnati', 'OH', 'US'),
#  ('Jefferson Street Grounds', 'Philadelphia', 'PA', 'US'),
#  ('Centennial Park', 'Philadelphia', 'PA', 'US'),
#  ('Oakdale Park', 'Philadelphia', 'PA', 'US'),
#  ('Recreation Park', 'Philadelphia', 'PA', 'US'),
#  ('Keystone Park', 'Philadelphia', 'PA', 'US'),
#  ('Huntingdon Grounds I', 'Philadelphia', 'PA', 'US'),
#  ('Forepaugh Park', 'Philadelphia', 'PA', 'US'),
#  ('University of Penn. Athletic Field', 'Philadelphia', 'PA', 'US'),
#  ('Baker Bowl', 'Philadelphia', 'PA', 'US'),
#  ('Columbia Park', 'Philadelphia', 'PA', 'US'),
#  ('Shibe Park', 'Philadelphia', 'PA', 'US'),
#  ('Veterans Stadium', 'Philadelphia', 'PA', 'US'),
#  ('Citizens Bank Park', 'Philadelphia', 'PA', 'US'),
#  ('Huntingdon Grounds II', 'Philadelphia', 'PA', 'US'),
#  ('Chase Field', 'Phoenix', 'AZ', 'US'),
#  ('Union Park', 'Pittsburgh', 'PA', 'US'),
#  ('Exposition Park I', 'Pittsburgh', 'PA', 'US'),
#  ('Exposition Park II', 'Pittsburgh', 'PA', 'US'),
#  ('Recreation Park', 'Pittsburgh', 'PA', 'US'),
#  ('Exposition Park III', 'Pittsburgh', 'PA', 'US'),
#  ('Forbes Field', 'Pittsburgh', 'PA', 'US'),
#  ('Three Rivers Stadium', 'Pittsburgh', 'PA', 'US'),
#  ('PNC Park', 'Pittsburgh', 'PA', 'US'),
#  ('Adelaide Avenue Grounds', 'Providence', 'RI', 'US'),
#  ('Messer Street Grounds', 'Providence', 'RI', 'US'),
#  ('Agricultural Society Fair Grounds', 'Rockford', 'IL', 'US'),
#  ('Richmond Fair Grounds', 'Richmond', 'VA', 'US'),
#  ('Allens Pasture', 'Richmond', 'VA', 'US'),
#  ('Culver Field I', 'Rochester', 'NY', 'US'),
#  ('Culver Field II', 'Rochester', 'NY', 'US'),
#  ('Ontario Beach Grounds', 'Rochester', 'NY', 'US'),
#  ('St. George Cricket Grounds', 'New York', 'NY', 'US'),
#  ('Qualcomm Stadium', 'San Diego', 'CA', 'US'),
#  ('PETCO Park', 'San Diego', 'CA', 'US'),
#  ("Sick's Stadium", 'Seattle', 'WA', 'US'),
#  ('Kingdome', 'Seattle', 'WA', 'US'),
#  ('Safeco Field', 'Seattle', 'WA', 'US'),
#  ('Seals Stadium', 'San Francisco', 'CA', 'US')]

# %% [markdown]
# ### Converting to pandas DataFrames
# To make get a proper dataframe just use the `.DataFrame` method of the resultset

# %%
parks_df = parks.DataFrame()
parks_df
# Out:
#                               parkname            city            state  \
# 0                     Candlestick Park   San Francisco               CA
# 1                            AT&T Park   San Francisco               CA
# 2                Estadio Hiram Bithorn        San Juan             None
# 3              Hampden Park Race Track     Springfield               MA
# 4         Red Stockings Base Ball Park       St. Louis               MO
# 5                    Grand Avenue Park       St. Louis               MO
# 6                   Sportsman's Park I       St. Louis               MO
# 7                        Union Grounds       St. Louis               MO
# 8                        Robison Field       St. Louis               MO
# 9                  Sportsman's Park II       St. Louis               MO
# 10                Sportsman's Park III       St. Louis               MO
# 11                      Handlan's Park       St. Louis               MO
# 12                    Busch Stadium II       St. Louis               MO
# 13                   Busch Stadium III       St. Louis               MO
# 14                     Tropicana Field  St. Petersburg               FL
# 15               Sydney Cricket Ground          Sydney  New South Wales
# 16                         Star Park I        Syracuse               NY
# 17                        Star Park II        Syracuse               NY
# 18                           Iron Pier        Syracuse               NY
# 19                   Three Rivers Park    Three Rivers               NY
# 20                          Tokyo Dome           Tokyo            Tokyo
# 21                         League Park          Toledo               OH
# 22              Tri-State Fair Grounds          Toledo               OH
# 23                       Speranza Park          Toledo               OH
# 24                         Armory Park          Toledo               OH
# 25                  Exhibition Stadium         Toronto               ON
# 26                       Rogers Centre         Toronto               ON
# 27                  Haymakers' Grounds            Troy               NY
# 28                      Putnam Grounds            Troy               NY
# 29                    Rocky Point Park         Warwick               RI
# ..                                 ...             ...              ...
# 220                         Baker Bowl    Philadelphia               PA
# 221                      Columbia Park    Philadelphia               PA
# 222                         Shibe Park    Philadelphia               PA
# 223                   Veterans Stadium    Philadelphia               PA
# 224                 Citizens Bank Park    Philadelphia               PA
# 225              Huntingdon Grounds II    Philadelphia               PA
# 226                        Chase Field         Phoenix               AZ
# 227                         Union Park      Pittsburgh               PA
# 228                  Exposition Park I      Pittsburgh               PA
# 229                 Exposition Park II      Pittsburgh               PA
# 230                    Recreation Park      Pittsburgh               PA
# 231                Exposition Park III      Pittsburgh               PA
# 232                       Forbes Field      Pittsburgh               PA
# 233               Three Rivers Stadium      Pittsburgh               PA
# 234                           PNC Park      Pittsburgh               PA
# 235            Adelaide Avenue Grounds      Providence               RI
# 236              Messer Street Grounds      Providence               RI
# 237  Agricultural Society Fair Grounds        Rockford               IL
# 238              Richmond Fair Grounds        Richmond               VA
# 239                     Allens Pasture        Richmond               VA
# 240                     Culver Field I       Rochester               NY
# 241                    Culver Field II       Rochester               NY
# 242              Ontario Beach Grounds       Rochester               NY
# 243         St. George Cricket Grounds        New York               NY
# 244                   Qualcomm Stadium       San Diego               CA
# 245                         PETCO Park       San Diego               CA
# 246                     Sick's Stadium         Seattle               WA
# 247                           Kingdome         Seattle               WA
# 248                       Safeco Field         Seattle               WA
# 249                      Seals Stadium   San Francisco               CA
#
#     country
# 0        US
# 1        US
# 2        PR
# 3        US
# 4        US
# 5        US
# 6        US
# 7        US
# 8        US
# 9        US
# 10       US
# 11       US
# 12       US
# 13       US
# 14       US
# 15       AU
# 16       US
# 17       US
# 18       US
# 19       US
# 20       JP
# 21       US
# 22       US
# 23       US
# 24       US
# 25       CA
# 26       CA
# 27       US
# 28       US
# 29       US
# ..      ...
# 220      US
# 221      US
# 222      US
# 223      US
# 224      US
# 225      US
# 226      US
# 227      US
# 228      US
# 229      US
# 230      US
# 231      US
# 232      US
# 233      US
# 234      US
# 235      US
# 236      US
# 237      US
# 238      US
# 239      US
# 240      US
# 241      US
# 242      US
# 243      US
# 244      US
# 245      US
# 246      US
# 247      US
# 248      US
# 249      US
#
# [250 rows x 4 columns]

# %% [markdown]
# ### Using `%%sql` resultsets
# When using `%%sql` the entire cell is SQL code. So, how do we get the results into Python if we can't use Python code in the cell? It's simple, really, just use the `__` pseudo-variable. It always holds the results of the most recently run cell. As long as we take care to have our Python code in the cell immediately after the `%%sql` magic, we should be fine.

# %%
# %%sql
# SELECT parkname, city, state, country
# FROM Parks
# LIMIT 10
# Out:
#  * sqlite:///lahman2016.sqlite
# Done.
# [('Candlestick Park', 'San Francisco', 'CA', 'US'),
#  ('AT&T Park', 'San Francisco', 'CA', 'US'),
#  ('Estadio Hiram Bithorn', 'San Juan', None, 'PR'),
#  ('Hampden Park Race Track', 'Springfield', 'MA', 'US'),
#  ('Red Stockings Base Ball Park', 'St. Louis', 'MO', 'US'),
#  ('Grand Avenue Park', 'St. Louis', 'MO', 'US'),
#  ("Sportsman's Park I", 'St. Louis', 'MO', 'US'),
#  ('Union Grounds', 'St. Louis', 'MO', 'US'),
#  ('Robison Field', 'St. Louis', 'MO', 'US'),
#  ("Sportsman's Park II", 'St. Louis', 'MO', 'US')]

# %%
parks_df = _.DataFrame()
parks_df
# Out:
#                        parkname           city state country
# 0              Candlestick Park  San Francisco    CA      US
# 1                     AT&T Park  San Francisco    CA      US
# 2         Estadio Hiram Bithorn       San Juan  None      PR
# 3       Hampden Park Race Track    Springfield    MA      US
# 4  Red Stockings Base Ball Park      St. Louis    MO      US
# 5             Grand Avenue Park      St. Louis    MO      US
# 6            Sportsman's Park I      St. Louis    MO      US
# 7                 Union Grounds      St. Louis    MO      US
# 8                 Robison Field      St. Louis    MO      US
# 9           Sportsman's Park II      St. Louis    MO      US

# %% [markdown]
# ### Using multiple databases
# Sometimes you will want to *port* data from one database to another. In this case, you will need to connect to both database at the same time.
#
# The trick is to specify the database connection string for each %sql call.
# ```python
# %sql <connection-for-db1>
# result_db1 = %sql SELECT * FROM ...
# %sql <connection-for_db2>
# %sql INSERT ...
# ```
